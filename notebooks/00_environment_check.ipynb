# %% [markdown]
# # Environment Check
#
# Use this notebook to verify the Jupyter runtime, Python packages, and GPU availability before training.

# %%
import sys
import platform

print(sys.version)
print(platform.platform())

# %%
import torch

print('cuda_available =', torch.cuda.is_available())
if torch.cuda.is_available():
    print('device =', torch.cuda.get_device_name(0))
