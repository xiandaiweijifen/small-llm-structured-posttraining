# %% [markdown]
# # 20 Action Template Latent Suite
#
# Train and evaluate a latent-action variant where the model predicts an `action` template ID and a deterministic renderer converts it back to the canonical action string before evaluation.

# %%
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
while project_root != project_root.parent and not (project_root / 'scripts').exists():
    project_root = project_root.parent

print('project_root =', project_root)

completed = subprocess.run(
    [sys.executable, str(project_root / 'scripts' / 'run_action_template_latent_suite.py')],
    check=True,
)
completed
