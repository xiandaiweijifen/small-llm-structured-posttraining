# %% [markdown]
# # Component Canonicalization Suite
#
# This notebook launches a smaller target-design batch focused on `affected_systems[0].component`.
#
# It batch-runs:
#
# - a `component-only` canonicalization control
# - joint `action + component` canonicalization in single-stage training
# - a joint staged variant using the strongest canonical-action recipe family

# %%
# Uncomment this once in a fresh online environment if needed.
# %pip install -q transformers datasets peft accelerate trl bitsandbytes pyyaml jsonschema

# %%
from pathlib import Path
import runpy
import sys


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'configs').exists() and (candidate / 'src').exists():
            return candidate
    raise RuntimeError('Could not find project root')


PROJECT_ROOT = find_project_root(Path.cwd())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print('project_root =', PROJECT_ROOT)
script_path = PROJECT_ROOT / 'scripts' / 'run_component_canonicalization_suite.py'
print('script_path =', script_path)
runpy.run_path(str(script_path), run_name='__main__')
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining
# script_path = /home/lyan11/small-llm-structured-posttraining/scripts/run_component_canonicalization_suite.py
# project_root = /home/lyan11/small-llm-structured-posttraining
# python = 3.13.11 | packaged by conda-forge | (main, Dec  6 2025, 11:24:03) [GCC 14.3.0]
# cuda_available = True
# device = NVIDIA H200 NVL
# bf16_supported = True
# scheduled_presets = ['canonical_component_only_single_stage_epoch7_lr2e4', 'canonical_action_component_single_stage_epoch5_lr2e4', 'canonical_action_component_single_stage_epoch7_lr2e4', 'canonical_action_component_structure_then_semantics_stage2_epoch9']
# skip_completed = True
# train = 1993
# val = 247
# test = 254
# component_mapping_stats = {'unique_names': 279, 'deterministic_name_fraction': 0.45161290322580644, 'weighted_majority_fraction': 0.6748620170597089}
#
# ================================================================================
# running preset = canonical_component_only_single_stage_epoch7_lr2e4
# ================================================================================
# train_bucket_counts = {'complex': 132, 'medium': 1392, 'simple': 469}
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Map:   0%|          | 0/247 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='441' max='441' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [441/441 05:34, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.727153</td>
#       <td>0.685460</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.536154</td>
#       <td>0.524023</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.427090</td>
#       <td>0.442593</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.376225</td>
#       <td>0.402659</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.347547</td>
#       <td>0.379468</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.296727</td>
#       <td>0.370962</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.290859</td>
#       <td>0.368816</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.260205</td>
#       <td>0.371462</td>
#     </tr>
#   </tbody>
# </table><p>
# The following generation flags are not valid and may be ignored: ['top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# train_loss = 0.5465115821685921
# generated 25 / 254
# generated 50 / 254
# generated 75 / 254
# generated 100 / 254
# generated 125 / 254
# generated 150 / 254
# generated 175 / 254
# generated 200 / 254
# generated 225 / 254
# generated 250 / 254
#
# ================================================================================
# running preset = canonical_action_component_single_stage_epoch5_lr2e4
# ================================================================================
# train_bucket_counts = {'complex': 132, 'medium': 1392, 'simple': 469}
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Map:   0%|          | 0/247 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='315' max='315' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [315/315 04:00, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.681888</td>
#       <td>0.650200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.520697</td>
#       <td>0.510067</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.422122</td>
#       <td>0.437602</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.379018</td>
#       <td>0.399831</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.351468</td>
#       <td>0.379065</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.308041</td>
#       <td>0.375162</td>
#     </tr>
#   </tbody>
# </table><p>
# train_loss = 0.6451345458863273
# generated 25 / 254
# generated 50 / 254
# generated 75 / 254
# generated 100 / 254
# generated 125 / 254
# generated 150 / 254
# generated 175 / 254
# generated 200 / 254
# generated 225 / 254
# generated 250 / 254
#
# ================================================================================
# running preset = canonical_action_component_single_stage_epoch7_lr2e4
# ================================================================================
# train_bucket_counts = {'complex': 132, 'medium': 1392, 'simple': 469}
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Map:   0%|          | 0/247 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/1993 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='441' max='441' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [441/441 05:35, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.684866</td>
#       <td>0.651780</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.520484</td>
#       <td>0.508913</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.418100</td>
#       <td>0.433050</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.371374</td>
#       <td>0.393797</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.342075</td>
#       <td>0.370793</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.292651</td>
#       <td>0.364043</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.288374</td>
#       <td>0.360197</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.260902</td>
#       <td>0.360919</td>
#     </tr>
#   </tbody>
# </table><p>
# train_loss = 0.5333990436089553
# generated 25 / 254
# generated 50 / 254
# generated 75 / 254
# generated 100 / 254
# generated 125 / 254
# generated 150 / 254
# generated 175 / 254
# generated 200 / 254
# generated 225 / 254
# generated 250 / 254
#
# ================================================================================
# running preset = canonical_action_component_structure_then_semantics_stage2_epoch9
# ================================================================================
# train_bucket_counts = {'complex': 132, 'medium': 1392, 'simple': 469}
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1861 [00:00<?, ? examples/s]
# Map:   0%|          | 0/247 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/1861 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/1861 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/247 [00:00<?, ? examples/s]
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': None, 'pad_token_id': 151643}.
#     <div>
#
#       <progress value='18' max='59' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [18/59 00:18 < 00:46, 0.88 it/s, Epoch 0.29/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
