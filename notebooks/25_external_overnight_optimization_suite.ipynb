# %% [markdown]
# # 25 External Overnight Optimization Suite
#
# Run a larger overnight external optimization batch that combines two directions:
#
# - deeper targeted continuation on top of the strongest Stage 14 external adapter
# - external-train-driven deterministic postprocess variants, especially `component <- name`
#
# This launcher is intended for long unattended runs on H200.

# %%
# %pip install -q datasets peft trl transformers "bitsandbytes>=0.46.1"
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import subprocess
import sys


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'configs').exists() and (candidate / 'src').exists():
            return candidate
    raise RuntimeError('Could not find project root')


project_root = find_project_root(Path.cwd())
print('project_root =', project_root)
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining

# %%
completed = subprocess.run(
    [
        sys.executable,
        str(project_root / 'scripts' / 'run_external_overnight_optimization_suite.py'),
    ],
    check=True,
)
completed
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining
# python = 3.13.11 | packaged by conda-forge | (main, Dec  6 2025, 11:24:03) [GCC 14.3.0]
# cuda_available = True
# device = NVIDIA H200 NVL
# bf16_supported = True
# has_bnb_4bit = True
# baseline_checkpoint_dir = /home/lyan11/small-llm-structured-posttraining/results/checkpoints/qwen25_3b_stage13_ext1024_epoch3_lr1e4
# scheduled_presets = ['target_component_category_x1_epoch1_lr5e5', 'target_component_category_x2_epoch1_lr5e5', 'target_category_priority_x1_epoch1_lr5e5', 'target_allcore_x1_epoch1_lr5e5', 'target_allcore_x1_epoch1_lr1e4']
# skip_completed = True
# skip_existing_mining = True
# inference_batch_size = 24
# Loading weights: 100%|██████████| 434/434 [00:00<00:00, 527.03it/s]
# The following generation flags are not valid and may be ignored: ['top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# targeted_subset_summary =
# {
#   "component_or_category": {
#     "num_records": 4763,
# ...
