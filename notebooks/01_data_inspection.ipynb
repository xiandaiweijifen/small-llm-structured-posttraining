# %% [markdown]
# # Data Inspection
#
# Use this notebook to inspect phase-1 candidate data, split summaries, and mapped sample quality.

# %%
import json
from pathlib import Path

summary_path = Path('data/samples/phase1_split_summary.json')
print(summary_path.read_text(encoding='utf-8'))

# %%
sample_path = Path('data/samples/phase1_candidate.jsonl')
with sample_path.open('r', encoding='utf-8') as handle:
    for idx, line in enumerate(handle):
        if idx >= 3:
            break
        print(json.loads(line))
        print('---')
