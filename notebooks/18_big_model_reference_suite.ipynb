# %% [markdown]
# # Big Model Reference Suite
#
# This notebook batch-runs multiple larger prompt-only reference models on the canonicalized reduced-schema task.
# It exports raw, repaired, deterministic-postprocessed, and lexical-postprocessed results in the standard format.

# %%
# %pip install -q transformers datasets accelerate bitsandbytes trl peft pyyaml jsonschema

# %%
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
if not (project_root / 'scripts').exists():
    project_root = project_root.parent
print('project_root =', project_root)
subprocess.run(
    [sys.executable, str(project_root / 'scripts' / 'run_big_model_reference_suite.py')],
    check=True,
    cwd=project_root,
)
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining
# project_root = /home/lyan11/small-llm-structured-posttraining
# scheduled_models = ['Qwen/Qwen2.5-3B-Instruct', 'Qwen/Qwen2.5-7B-Instruct', 'Qwen/Qwen2.5-14B-Instruct', 'Qwen/Qwen2.5-32B-Instruct']
# skip_completed = True
#
# ...
# model = Qwen/Qwen2.5-3B-Instruct
# experiment = qwen25_3b_reference_canonical_prompt
# batch_size = 32
# ...
#
# ...
# model = Qwen/Qwen2.5-7B-Instruct
# experiment = qwen25_7b_reference_canonical_prompt
# batch_size = 24
# ...
# Loading weights: 100%|██████████| 339/339 [00:01<00:00, 176.44it/s]
# The following generation flags are not valid and may be ignored: ['top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ...
# model = Qwen/Qwen2.5-14B-Instruct
# experiment = qwen25_14b_reference_canonical_prompt
# batch_size = 12
# ...
# Loading weights: 100%|██████████| 579/579 [02:10<00:00,  4.45it/s]
# ...
# model = Qwen/Qwen2.5-32B-Instruct
# experiment = qwen25_32b_reference_canonical_prompt
# batch_size = 6
# ...
