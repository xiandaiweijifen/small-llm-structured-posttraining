# %% [markdown]
# # 24 External Targeted Adaptation Suite
#
# Mine the strongest Stage 13 external-adaptation checkpoint on the external train split, then run targeted external continuation presets focused on taxonomy-heavy fields such as component, category, and priority.

# %%
# %pip install -q datasets peft trl transformers "bitsandbytes>=0.46.1"

# %%
from pathlib import Path
import subprocess
import sys


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'configs').exists() and (candidate / 'src').exists():
            return candidate
    raise RuntimeError('Could not find project root')


project_root = find_project_root(Path.cwd())
print('project_root =', project_root)

# %%
completed = subprocess.run(
    [
        sys.executable,
        str(project_root / 'scripts' / 'run_external_targeted_adaptation_suite.py'),
    ],
    check=True,
)
completed
