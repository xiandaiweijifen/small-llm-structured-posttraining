# %% [markdown]
# # Stage 8 Deterministic Postprocess Suite
#
# This notebook runs fast, CPU-side postprocessing experiments on the current Stage 7 best predictions.
# It does not retrain the model.

# %%
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
if not (project_root / 'scripts').exists():
    project_root = project_root.parent
print('project_root =', project_root)
subprocess.run(
    [sys.executable, str(project_root / 'scripts' / 'run_deterministic_postprocess_suite.py')],
    check=True,
    cwd=project_root,
)
