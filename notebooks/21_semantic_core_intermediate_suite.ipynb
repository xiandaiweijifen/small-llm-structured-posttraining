# %% [markdown]
# # 21 Semantic Core Intermediate Suite
#
# Train and evaluate a true semantic-core intermediate representation, then deterministically render it back to the reduced schema before evaluation.

# %%
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
while project_root != project_root.parent and not (project_root / 'scripts').exists():
    project_root = project_root.parent

print('project_root =', project_root)

completed = subprocess.run(
    [sys.executable, str(project_root / 'scripts' / 'run_semantic_core_intermediate_suite.py')],
    check=True,
)
completed
