# %% [markdown]
# # 28 Internal External Mismatch Audit
#
# Run a focused mismatch audit between the in-domain reduced training set and the mapped external customer-support dataset.

# %%
# %pip install -q datasets
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import subprocess
import sys

def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'scripts').exists() and (candidate / 'docs').exists():
            return candidate
    raise RuntimeError('Could not find project root')

project_root = find_project_root(Path.cwd())
print('project_root =', project_root)
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining

# %%
completed = subprocess.run(
    [
        sys.executable,
        str(project_root / 'scripts' / 'run_internal_external_mismatch_audit.py'),
    ],
    check=True,
)
completed
# Out:
# internal_train = /home/lyan11/small-llm-structured-posttraining/data/reduced/phase1_train_reduced.jsonl
# external_train = /home/lyan11/small-llm-structured-posttraining/data/external_generalization/gorkemsevinc_customer_support_tickets_train_reduced.jsonl
# external_test = /home/lyan11/small-llm-structured-posttraining/data/external_generalization/gorkemsevinc_customer_support_tickets_test_reduced.jsonl
# summary_json = /home/lyan11/small-llm-structured-posttraining/docs/results/internal_external_mismatch_audit.json
# summary_md = /home/lyan11/small-llm-structured-posttraining/docs/results/internal_external_mismatch_audit.md
# CompletedProcess(args=['/opt/conda/bin/python', '/home/lyan11/small-llm-structured-posttraining/scripts/run_internal_external_mismatch_audit.py'], returncode=0)
