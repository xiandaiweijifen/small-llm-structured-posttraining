# %% [markdown]
# # End-to-End Optimization Suite
#
# This notebook launches the broader Stage 3 end-to-end optimization batch.
#
# It will:
#
# - mine hard training samples using the current strongest staged-training checkpoint
# - run multiple continuation presets automatically
# - export a markdown summary and leaderboard

# %%
# Uncomment this once in a fresh online environment if needed.
# %pip install -q transformers datasets peft accelerate trl bitsandbytes pyyaml jsonschema

# %%
from pathlib import Path
import runpy
import sys


def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'configs').exists() and (candidate / 'src').exists():
            return candidate
    raise RuntimeError('Could not find project root')


PROJECT_ROOT = find_project_root(Path.cwd())
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print('project_root =', PROJECT_ROOT)
script_path = PROJECT_ROOT / 'scripts' / 'run_end_to_end_optimization_suite.py'
print('script_path =', script_path)
runpy.run_path(str(script_path), run_name='__main__')
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining
# script_path = /home/lyan11/small-llm-structured-posttraining/scripts/run_end_to_end_optimization_suite.py
# project_root = /home/lyan11/small-llm-structured-posttraining
# python = 3.13.11 | packaged by conda-forge | (main, Dec  6 2025, 11:24:03) [GCC 14.3.0]
# cuda_available = True
# device = NVIDIA H200 NVL
# bf16_supported = True
# miner_checkpoint_dir = /home/lyan11/small-llm-structured-posttraining/results/checkpoints/qwen25_3b_stage2_structure_then_semantics_v1
# scheduled_presets = ['sts_v2_hard_only_x4_epoch1_lr5e5', 'sts_v2_full_plus_hard_x2_epoch2_lr1e4', 'sts_v2_full_plus_hard_x3_epoch2_lr1e4', 'sts_v2_full_plus_hard_x2_epoch2_lr5e5']
# skip_completed = True
# skip_existing_mining = True
# train = 1993
# val = 247
# test = 254
# Loading weights:   0%|          | 0/434 [00:00<?, ?it/s]
# ...
