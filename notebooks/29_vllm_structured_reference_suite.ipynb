# %% [markdown]
# # 29 vLLM Structured Reference Suite
#
# Re-evaluate same-family prompt-only references with vLLM raw decoding and vLLM JSON-schema structured outputs.

# %%
# %pip install -q vllm

# %%
from pathlib import Path
import subprocess
import sys

def find_project_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'scripts').exists() and (candidate / 'docs').exists():
            return candidate
    raise RuntimeError('Could not find project root')

project_root = find_project_root(Path.cwd())
print('project_root =', project_root)
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining

# %%
completed = subprocess.run(
    [
        sys.executable,
        str(project_root / 'scripts' / 'run_vllm_structured_reference_suite.py'),
    ],
    check=True,
)
completed
# Out:
# project_root = /home/lyan11/small-llm-structured-posttraining
# guided_backend = None
# structured_mode = structured_outputs
# scheduled_models = ['Qwen/Qwen2.5-3B-Instruct', 'Qwen/Qwen2.5-7B-Instruct', 'Qwen/Qwen2.5-14B-Instruct', 'Qwen/Qwen2.5-32B-Instruct']
# skip_completed = True
#
# ...
# model = Qwen/Qwen2.5-3B-Instruct
# experiment = qwen25_3b_vllm_reference
# ...
# INFO 03-24 12:03:56 [utils.py:233] non-default args: {'trust_remote_code': True, 'dtype': 'bfloat16', 'max_model_len': 2048, 'gpu_memory_utilization': 0.92, 'max_num_seqs': 64, 'disable_log_stats': True, 'model': 'Qwen/Qwen2.5-3B-Instruct'}
# INFO 03-24 12:04:05 [model.py:533] Resolved architecture: Qwen2ForCausalLM
# INFO 03-24 12:04:05 [model.py:1582] Using max model len 2048
# INFO 03-24 12:04:05 [scheduler.py:231] Chunked prefill is enabled with max_num_batched_tokens=16384.
# INFO 03-24 12:04:05 [vllm.py:754] Asynchronous scheduling is enabled.
# ...
